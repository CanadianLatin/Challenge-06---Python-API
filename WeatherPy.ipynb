# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of ciudades

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the ciudades based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the ciudades List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
latitud_ln = []

# Empty list for holding the ciudades names
ciudades = []

# Range of latitudes and longitudes
latitude_range = (-90, 90)
longitud_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(latitude_range[0], latitude_range[1], size=1500)
lngs = np.random.uniform(longitud_range[0], longitud_range[1], size=1500)
latitud_ln = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in latitud_ln:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our ciudades list
    if city not in ciudades:
        ciudades.append(city)

# Print the city count to confirm sufficient count
print(f"Number of ciudades in the list: {len(ciudades)}")
# Out:
# Number of ciudades in the list: 598

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the ciudades list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key

# Define an empty list to fetch the weather data for each city
citi_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
setting_count = 1

# Loop through all the ciudades in our list to fetch weather data
for i, city in enumerate(ciudades):
        
    # Group ciudades in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        setting_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, setting_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the ciudades
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into citi_data list
        citi_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | inuvik
# Processing Record 2 of Set 1 | vaitape
# Processing Record 3 of Set 1 | ejura
# Processing Record 4 of Set 1 | swellendam
# Processing Record 5 of Set 1 | esperance
# Processing Record 6 of Set 1 | hoquiam
# Processing Record 7 of Set 1 | necochea
# Processing Record 8 of Set 1 | georgetown
# Processing Record 9 of Set 1 | okhotsk
# Processing Record 10 of Set 1 | atuona
# Processing Record 11 of Set 1 | butaritari
# Processing Record 12 of Set 1 | jamestown
# Processing Record 13 of Set 1 | leh
# Processing Record 14 of Set 1 | shelburne
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 1 | wanning
# Processing Record 18 of Set 1 | sao joao da barra
# Processing Record 19 of Set 1 | fort frances
# Processing Record 20 of Set 1 | rawson
# Processing Record 21 of Set 1 | yegorlykskaya
# Processing Record 22 of Set 1 | rabat
# Processing Record 23 of Set 1 | new norfolk
# Processing Record 24 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 25 of Set 1 | wattegama
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | busselton
# Processing Record 28 of Set 1 | sumbawanga
# Processing Record 29 of Set 1 | bluff
# Processing Record 30 of Set 1 | cherskiy
# Processing Record 31 of Set 1 | yalchiki
# City not found. Skipping...
# Processing Record 32 of Set 1 | kruisfontein
# Processing Record 33 of Set 1 | ribeira grande
# Processing Record 34 of Set 1 | port elizabeth
# Processing Record 35 of Set 1 | mandalgovi
# Processing Record 36 of Set 1 | san patricio
# Processing Record 37 of Set 1 | tiksi
# Processing Record 38 of Set 1 | tarauaca
# Processing Record 39 of Set 1 | bani walid
# Processing Record 40 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 1 | yarim
# Processing Record 42 of Set 1 | port hawkesbury
# Processing Record 43 of Set 1 | chapais
# Processing Record 44 of Set 1 | saint cloud
# Processing Record 45 of Set 1 | launceston
# Processing Record 46 of Set 1 | pisco
# Processing Record 47 of Set 1 | saskylakh
# Processing Record 48 of Set 1 | bethel
# Processing Record 49 of Set 1 | nikolskoye
# Processing Record 50 of Set 1 | hermanus
# Processing Record 0 of Set 2 | mehamn
# Processing Record 1 of Set 2 | puerto ayora
# Processing Record 2 of Set 2 | ilulissat
# Processing Record 3 of Set 2 | nikolayevsk-na-amure
# Processing Record 4 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 2 | tabas
# Processing Record 6 of Set 2 | severo-kurilsk
# Processing Record 7 of Set 2 | hilo
# Processing Record 8 of Set 2 | barrow
# Processing Record 9 of Set 2 | vaini
# Processing Record 10 of Set 2 | ostrovnoy
# Processing Record 11 of Set 2 | punta arenas
# Processing Record 12 of Set 2 | nago
# Processing Record 13 of Set 2 | gizo
# Processing Record 14 of Set 2 | anamur
# Processing Record 15 of Set 2 | ushuaia
# Processing Record 16 of Set 2 | tooele
# Processing Record 17 of Set 2 | port alfred
# Processing Record 18 of Set 2 | kyaikkami
# Processing Record 19 of Set 2 | touros
# Processing Record 20 of Set 2 | provideniya
# Processing Record 21 of Set 2 | port blair
# Processing Record 22 of Set 2 | saint-philippe
# Processing Record 23 of Set 2 | oranjestad
# Processing Record 24 of Set 2 | praia
# Processing Record 25 of Set 2 | victoria
# Processing Record 26 of Set 2 | menongue
# Processing Record 27 of Set 2 | havre
# Processing Record 28 of Set 2 | yanchukan
# City not found. Skipping...
# Processing Record 29 of Set 2 | mayumba
# Processing Record 30 of Set 2 | dauphin
# Processing Record 31 of Set 2 | mataura
# Processing Record 32 of Set 2 | esso
# Processing Record 33 of Set 2 | walvis bay
# Processing Record 34 of Set 2 | navahrudak
# Processing Record 35 of Set 2 | thompson
# Processing Record 36 of Set 2 | warwick
# Processing Record 37 of Set 2 | brae
# Processing Record 38 of Set 2 | cabedelo
# Processing Record 39 of Set 2 | turukhansk
# Processing Record 40 of Set 2 | khani
# Processing Record 41 of Set 2 | sechura
# Processing Record 42 of Set 2 | moroni
# Processing Record 43 of Set 2 | vila franca do campo
# Processing Record 44 of Set 2 | bubaque
# Processing Record 45 of Set 2 | bredasdorp
# Processing Record 46 of Set 2 | ligayan
# Processing Record 47 of Set 2 | yovon
# Processing Record 48 of Set 2 | jiazi
# Processing Record 49 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 0 of Set 3 | vera cruz
# Processing Record 1 of Set 3 | yulara
# Processing Record 2 of Set 3 | erzin
# Processing Record 3 of Set 3 | kodiak
# Processing Record 4 of Set 3 | hobart
# Processing Record 5 of Set 3 | mar del plata
# Processing Record 6 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 3 | mahebourg
# Processing Record 8 of Set 3 | hit
# Processing Record 9 of Set 3 | hervey bay
# Processing Record 10 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 3 | makakilo city
# Processing Record 12 of Set 3 | dikson
# Processing Record 13 of Set 3 | bandarbeyla
# Processing Record 14 of Set 3 | macaboboni
# City not found. Skipping...
# Processing Record 15 of Set 3 | yar-sale
# Processing Record 16 of Set 3 | san javier
# Processing Record 17 of Set 3 | lenki
# City not found. Skipping...
# Processing Record 18 of Set 3 | urucara
# Processing Record 19 of Set 3 | khatanga
# Processing Record 20 of Set 3 | pilar
# Processing Record 21 of Set 3 | castro
# Processing Record 22 of Set 3 | cururupu
# Processing Record 23 of Set 3 | egvekinot
# Processing Record 24 of Set 3 | prince george
# Processing Record 25 of Set 3 | dalvik
# Processing Record 26 of Set 3 | omboue
# Processing Record 27 of Set 3 | te anau
# Processing Record 28 of Set 3 | sao filipe
# Processing Record 29 of Set 3 | luderitz
# Processing Record 30 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 3 | callaway
# Processing Record 32 of Set 3 | niort
# Processing Record 33 of Set 3 | barghat
# Processing Record 34 of Set 3 | shasta lake
# Processing Record 35 of Set 3 | komsomolskiy
# Processing Record 36 of Set 3 | east london
# Processing Record 37 of Set 3 | upernavik
# Processing Record 38 of Set 3 | sompeta
# Processing Record 39 of Set 3 | magistralnyy
# Processing Record 40 of Set 3 | souillac
# Processing Record 41 of Set 3 | kirya
# Processing Record 42 of Set 3 | sistranda
# Processing Record 43 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 44 of Set 3 | westerland
# Processing Record 45 of Set 3 | arlit
# Processing Record 46 of Set 3 | tuktoyaktuk
# Processing Record 47 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 3 | turbat
# Processing Record 49 of Set 3 | yellowknife
# Processing Record 0 of Set 4 | longyearbyen
# Processing Record 1 of Set 4 | naze
# Processing Record 2 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 4 | kahului
# Processing Record 4 of Set 4 | kavieng
# Processing Record 5 of Set 4 | tornio
# Processing Record 6 of Set 4 | clyde river
# Processing Record 7 of Set 4 | grand gaube
# Processing Record 8 of Set 4 | dunedin
# Processing Record 9 of Set 4 | bambous virieux
# Processing Record 10 of Set 4 | ahipara
# Processing Record 11 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 4 | saint george
# Processing Record 13 of Set 4 | bratsk
# Processing Record 14 of Set 4 | cabo san lucas
# Processing Record 15 of Set 4 | kefamenanu
# Processing Record 16 of Set 4 | vilhena
# Processing Record 17 of Set 4 | oyem
# Processing Record 18 of Set 4 | abaetetuba
# Processing Record 19 of Set 4 | cape town
# Processing Record 20 of Set 4 | ucluelet
# Processing Record 21 of Set 4 | mount gambier
# Processing Record 22 of Set 4 | sehwan
# Processing Record 23 of Set 4 | ozark
# Processing Record 24 of Set 4 | westport
# Processing Record 25 of Set 4 | nara
# Processing Record 26 of Set 4 | muros
# Processing Record 27 of Set 4 | rundu
# Processing Record 28 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 29 of Set 4 | cidreira
# Processing Record 30 of Set 4 | teneguiban
# City not found. Skipping...
# Processing Record 31 of Set 4 | kazachinskoye
# Processing Record 32 of Set 4 | bengkulu
# Processing Record 33 of Set 4 | along
# Processing Record 34 of Set 4 | canberra
# Processing Record 35 of Set 4 | dhrangadhra
# Processing Record 36 of Set 4 | livingston
# Processing Record 37 of Set 4 | caravelas
# Processing Record 38 of Set 4 | guerrero negro
# Processing Record 39 of Set 4 | stokmarknes
# Processing Record 40 of Set 4 | phan rang
# City not found. Skipping...
# Processing Record 41 of Set 4 | qaanaaq
# Processing Record 42 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 43 of Set 4 | rocha
# Processing Record 44 of Set 4 | umm lajj
# Processing Record 45 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 46 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 4 | adrar
# Processing Record 48 of Set 4 | celestun
# Processing Record 49 of Set 4 | karratha
# Processing Record 0 of Set 5 | hamilton
# Processing Record 1 of Set 5 | coahuayana
# Processing Record 2 of Set 5 | marystown
# Processing Record 3 of Set 5 | laguna
# Processing Record 4 of Set 5 | kaitangata
# Processing Record 5 of Set 5 | tacoronte
# Processing Record 6 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 5 | pevek
# Processing Record 8 of Set 5 | kyra
# Processing Record 9 of Set 5 | samarai
# Processing Record 10 of Set 5 | saint-augustin
# Processing Record 11 of Set 5 | lebu
# Processing Record 12 of Set 5 | novikovo
# Processing Record 13 of Set 5 | faya
# Processing Record 14 of Set 5 | vanimo
# Processing Record 15 of Set 5 | susurluk
# Processing Record 16 of Set 5 | tugolesskiy bor
# Processing Record 17 of Set 5 | baruun-urt
# Processing Record 18 of Set 5 | sinkat
# City not found. Skipping...
# Processing Record 19 of Set 5 | vila velha
# Processing Record 20 of Set 5 | bathsheba
# Processing Record 21 of Set 5 | tondano
# Processing Record 22 of Set 5 | mackay
# Processing Record 23 of Set 5 | jaipur hat
# City not found. Skipping...
# Processing Record 24 of Set 5 | lithgow
# Processing Record 25 of Set 5 | katiola
# Processing Record 26 of Set 5 | pervomayskoye
# Processing Record 27 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 28 of Set 5 | touho
# Processing Record 29 of Set 5 | houma
# Processing Record 30 of Set 5 | hambantota
# Processing Record 31 of Set 5 | madang
# Processing Record 32 of Set 5 | nevelsk
# Processing Record 33 of Set 5 | vardo
# Processing Record 34 of Set 5 | kapaa
# Processing Record 35 of Set 5 | bilibino
# Processing Record 36 of Set 5 | jiddah
# City not found. Skipping...
# Processing Record 37 of Set 5 | chontalpa
# Processing Record 38 of Set 5 | dong hoi
# Processing Record 39 of Set 5 | hornepayne
# Processing Record 40 of Set 5 | silvania
# Processing Record 41 of Set 5 | tateyama
# Processing Record 42 of Set 5 | phonhong
# Processing Record 43 of Set 5 | tuatapere
# Processing Record 44 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 45 of Set 5 | nouadhibou
# Processing Record 46 of Set 5 | fortuna
# Processing Record 47 of Set 5 | colares
# Processing Record 48 of Set 5 | sawtell
# Processing Record 49 of Set 5 | baykit
# Processing Record 0 of Set 6 | rezina
# Processing Record 1 of Set 6 | beyneu
# Processing Record 2 of Set 6 | carnarvon
# Processing Record 3 of Set 6 | coquimbo
# Processing Record 4 of Set 6 | grindavik
# Processing Record 5 of Set 6 | salalah
# Processing Record 6 of Set 6 | vestmanna
# Processing Record 7 of Set 6 | nanakuli
# Processing Record 8 of Set 6 | beringovskiy
# Processing Record 9 of Set 6 | bay roberts
# Processing Record 10 of Set 6 | faanui
# Processing Record 11 of Set 6 | seoul
# Processing Record 12 of Set 6 | bourges
# Processing Record 13 of Set 6 | talas
# Processing Record 14 of Set 6 | belaya gora
# Processing Record 15 of Set 6 | geraldton
# Processing Record 16 of Set 6 | lorengau
# Processing Record 17 of Set 6 | the pas
# Processing Record 18 of Set 6 | copiapo
# Processing Record 19 of Set 6 | saint-francois
# Processing Record 20 of Set 6 | stoyba
# City not found. Skipping...
# Processing Record 21 of Set 6 | port hardy
# Processing Record 22 of Set 6 | talnakh
# Processing Record 23 of Set 6 | bluefield
# Processing Record 24 of Set 6 | pangai
# Processing Record 25 of Set 6 | kloulklubed
# Processing Record 26 of Set 6 | harper
# Processing Record 27 of Set 6 | mazatlan
# Processing Record 28 of Set 6 | praia da vitoria
# Processing Record 29 of Set 6 | gotsu
# Processing Record 30 of Set 6 | bahia blanca
# Processing Record 31 of Set 6 | kalmunai
# Processing Record 32 of Set 6 | vangazi
# Processing Record 33 of Set 6 | hofn
# Processing Record 34 of Set 6 | deer lake
# Processing Record 35 of Set 6 | aklavik
# Processing Record 36 of Set 6 | pemangkat
# Processing Record 37 of Set 6 | chokurdakh
# Processing Record 38 of Set 6 | kandrian
# Processing Record 39 of Set 6 | saint-gaudens
# Processing Record 40 of Set 6 | antalaha
# Processing Record 41 of Set 6 | shenzhen
# Processing Record 42 of Set 6 | matata
# Processing Record 43 of Set 6 | arraial do cabo
# Processing Record 44 of Set 6 | narsaq
# Processing Record 45 of Set 6 | melfi
# Processing Record 46 of Set 6 | rock springs
# Processing Record 47 of Set 6 | cantagalo
# Processing Record 48 of Set 6 | dingzhou
# Processing Record 49 of Set 6 | lexington park
# Processing Record 0 of Set 7 | washougal
# Processing Record 1 of Set 7 | hithadhoo
# Processing Record 2 of Set 7 | taman
# Processing Record 3 of Set 7 | staryy nadym
# Processing Record 4 of Set 7 | dingle
# Processing Record 5 of Set 7 | union
# Processing Record 6 of Set 7 | olafsvik
# Processing Record 7 of Set 7 | wewak
# Processing Record 8 of Set 7 | umm durman
# City not found. Skipping...
# Processing Record 9 of Set 7 | abhayapuri
# Processing Record 10 of Set 7 | xuddur
# Processing Record 11 of Set 7 | norman wells
# Processing Record 12 of Set 7 | puerto escondido
# Processing Record 13 of Set 7 | amga
# Processing Record 14 of Set 7 | grants
# Processing Record 15 of Set 7 | leningradskiy
# Processing Record 16 of Set 7 | aykhal
# Processing Record 17 of Set 7 | darhan
# Processing Record 18 of Set 7 | chara
# Processing Record 19 of Set 7 | sur
# Processing Record 20 of Set 7 | kununurra
# Processing Record 21 of Set 7 | oksovskiy
# Processing Record 22 of Set 7 | srednekolymsk
# Processing Record 23 of Set 7 | henties bay
# Processing Record 24 of Set 7 | yinchuan
# Processing Record 25 of Set 7 | pangnirtung
# Processing Record 26 of Set 7 | malabo
# Processing Record 27 of Set 7 | aitape
# Processing Record 28 of Set 7 | coihaique
# Processing Record 29 of Set 7 | ketchikan
# Processing Record 30 of Set 7 | waingapu
# Processing Record 31 of Set 7 | marsa matruh
# Processing Record 32 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 7 | vestmannaeyjar
# Processing Record 34 of Set 7 | bo
# City not found. Skipping...
# Processing Record 35 of Set 7 | banda aceh
# Processing Record 36 of Set 7 | ajdabiya
# Processing Record 37 of Set 7 | namibe
# Processing Record 38 of Set 7 | sitka
# Processing Record 39 of Set 7 | santa isabel do rio negro
# Processing Record 40 of Set 7 | kidal
# Processing Record 41 of Set 7 | rio grande
# Processing Record 42 of Set 7 | cazaje
# City not found. Skipping...
# Processing Record 43 of Set 7 | muzhi
# Processing Record 44 of Set 7 | avarua
# Processing Record 45 of Set 7 | pakxan
# Processing Record 46 of Set 7 | santa cruz de la palma
# Processing Record 47 of Set 7 | uthal
# Processing Record 48 of Set 7 | kaduqli
# Processing Record 49 of Set 7 | anito
# Processing Record 0 of Set 8 | nome
# Processing Record 1 of Set 8 | topolobampo
# Processing Record 2 of Set 8 | taksimo
# Processing Record 3 of Set 8 | nabire
# Processing Record 4 of Set 8 | torbay
# Processing Record 5 of Set 8 | mashhad
# Processing Record 6 of Set 8 | luau
# Processing Record 7 of Set 8 | half moon bay
# Processing Record 8 of Set 8 | avera
# Processing Record 9 of Set 8 | gemena
# Processing Record 10 of Set 8 | sterling
# Processing Record 11 of Set 8 | thinadhoo
# Processing Record 12 of Set 8 | merta
# Processing Record 13 of Set 8 | tazovskiy
# Processing Record 14 of Set 8 | tasiilaq
# Processing Record 15 of Set 8 | batticaloa
# Processing Record 16 of Set 8 | qui nhon
# Processing Record 17 of Set 8 | bindi
# Processing Record 18 of Set 8 | pimentel
# Processing Record 19 of Set 8 | inhambane
# Processing Record 20 of Set 8 | ambilobe
# Processing Record 21 of Set 8 | rudnogorsk
# Processing Record 22 of Set 8 | flinders
# Processing Record 23 of Set 8 | deputatskiy
# Processing Record 24 of Set 8 | klaksvik
# Processing Record 25 of Set 8 | kieta
# Processing Record 26 of Set 8 | minot
# Processing Record 27 of Set 8 | aksarka
# Processing Record 28 of Set 8 | istok
# Processing Record 29 of Set 8 | chuy
# Processing Record 30 of Set 8 | benguela
# Processing Record 31 of Set 8 | mogadishu
# Processing Record 32 of Set 8 | tahara
# Processing Record 33 of Set 8 | maragogi
# Processing Record 34 of Set 8 | lamar
# Processing Record 35 of Set 8 | kobayashi
# Processing Record 36 of Set 8 | chumikan
# Processing Record 37 of Set 8 | cayenne
# Processing Record 38 of Set 8 | san cristobal
# Processing Record 39 of Set 8 | tucuman
# Processing Record 40 of Set 8 | bitung
# Processing Record 41 of Set 8 | port lincoln
# Processing Record 42 of Set 8 | nioro
# Processing Record 43 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 44 of Set 8 | tocopilla
# Processing Record 45 of Set 8 | san-pedro
# Processing Record 46 of Set 8 | portland
# Processing Record 47 of Set 8 | valparaiso
# Processing Record 48 of Set 8 | yasnyy
# Processing Record 49 of Set 8 | isangel
# Processing Record 0 of Set 9 | anzio
# Processing Record 1 of Set 9 | mandi bahauddin
# Processing Record 2 of Set 9 | terra santa
# Processing Record 3 of Set 9 | tefe
# Processing Record 4 of Set 9 | monoharpur
# Processing Record 5 of Set 9 | pineville
# Processing Record 6 of Set 9 | ilhabela
# Processing Record 7 of Set 9 | broome
# Processing Record 8 of Set 9 | kiunga
# Processing Record 9 of Set 9 | methala
# Processing Record 10 of Set 9 | morro bay
# Processing Record 11 of Set 9 | nantucket
# Processing Record 12 of Set 9 | graaff-reinet
# Processing Record 13 of Set 9 | hearst
# Processing Record 14 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 9 | buchanan
# Processing Record 16 of Set 9 | xixiang
# Processing Record 17 of Set 9 | batagay-alyta
# Processing Record 18 of Set 9 | katsuura
# Processing Record 19 of Set 9 | okha
# Processing Record 20 of Set 9 | villanueva de la serena
# Processing Record 21 of Set 9 | kumi
# Processing Record 22 of Set 9 | taoudenni
# Processing Record 23 of Set 9 | port-cartier
# Processing Record 24 of Set 9 | leshan
# Processing Record 25 of Set 9 | caluquembe
# Processing Record 26 of Set 9 | salto
# Processing Record 27 of Set 9 | tabory
# Processing Record 28 of Set 9 | torgau
# Processing Record 29 of Set 9 | alofi
# Processing Record 30 of Set 9 | saldanha
# Processing Record 31 of Set 9 | huazolotitlan
# City not found. Skipping...
# Processing Record 32 of Set 9 | heihe
# Processing Record 33 of Set 9 | litoral del san juan
# City not found. Skipping...
# Processing Record 34 of Set 9 | clacton-on-sea
# Processing Record 35 of Set 9 | carbonia
# Processing Record 36 of Set 9 | horta
# Processing Record 37 of Set 9 | gubkinskiy
# Processing Record 38 of Set 9 | krasnogvardeyskiy
# Processing Record 39 of Set 9 | berdigestyakh
# Processing Record 40 of Set 9 | minab
# Processing Record 41 of Set 9 | woodward
# Processing Record 42 of Set 9 | biltine
# Processing Record 43 of Set 9 | pandharpur
# Processing Record 44 of Set 9 | kuanshan
# City not found. Skipping...
# Processing Record 45 of Set 9 | beipiao
# Processing Record 46 of Set 9 | lompoc
# Processing Record 47 of Set 9 | salinopolis
# Processing Record 48 of Set 9 | anagni
# Processing Record 49 of Set 9 | asau
# Processing Record 0 of Set 10 | aksu
# Processing Record 1 of Set 10 | cabra
# Processing Record 2 of Set 10 | ponta do sol
# Processing Record 3 of Set 10 | bouca
# Processing Record 4 of Set 10 | turayf
# Processing Record 5 of Set 10 | conde
# Processing Record 6 of Set 10 | zwedru
# Processing Record 7 of Set 10 | moose factory
# Processing Record 8 of Set 10 | qasigiannguit
# Processing Record 9 of Set 10 | ceres
# Processing Record 10 of Set 10 | lamu
# Processing Record 11 of Set 10 | dotnuva
# Processing Record 12 of Set 10 | pathein
# Processing Record 13 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 14 of Set 10 | acarau
# Processing Record 15 of Set 10 | eyl
# Processing Record 16 of Set 10 | vrangel
# Processing Record 17 of Set 10 | aswan
# Processing Record 18 of Set 10 | fengxian
# Processing Record 19 of Set 10 | sambava
# Processing Record 20 of Set 10 | kayes
# Processing Record 21 of Set 10 | antropovo
# Processing Record 22 of Set 10 | husavik
# Processing Record 23 of Set 10 | qaqortoq
# Processing Record 24 of Set 10 | cairns
# Processing Record 25 of Set 10 | kailasahar
# City not found. Skipping...
# Processing Record 26 of Set 10 | kushmurun
# Processing Record 27 of Set 10 | ponta delgada
# Processing Record 28 of Set 10 | rehoboth
# Processing Record 29 of Set 10 | manzhouli
# Processing Record 30 of Set 10 | chifeng
# Processing Record 31 of Set 10 | miandrivazo
# Processing Record 32 of Set 10 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 33 of Set 10 | clermont
# Processing Record 34 of Set 10 | sisimiut
# Processing Record 35 of Set 10 | de aar
# Processing Record 36 of Set 10 | sioux lookout
# Processing Record 37 of Set 10 | voskresenskoye
# Processing Record 38 of Set 10 | vostok
# Processing Record 39 of Set 10 | hasaki
# Processing Record 40 of Set 10 | saint-paul
# Processing Record 41 of Set 10 | collie
# Processing Record 42 of Set 10 | yeppoon
# Processing Record 43 of Set 10 | bobcaygeon
# Processing Record 44 of Set 10 | ilebo
# Processing Record 45 of Set 10 | polovinnoye
# Processing Record 46 of Set 10 | el alto
# Processing Record 47 of Set 10 | metapan
# Processing Record 48 of Set 10 | tecolutilla
# Processing Record 49 of Set 10 | san jeronimo
# Processing Record 0 of Set 11 | namie
# Processing Record 1 of Set 11 | erenhot
# Processing Record 2 of Set 11 | iqaluit
# Processing Record 3 of Set 11 | kristinehamn
# Processing Record 4 of Set 11 | kouroussa
# Processing Record 5 of Set 11 | yanam
# Processing Record 6 of Set 11 | atar
# Processing Record 7 of Set 11 | urubicha
# Processing Record 8 of Set 11 | zharkent
# Processing Record 9 of Set 11 | asilah
# Processing Record 10 of Set 11 | dhidhdhoo
# Processing Record 11 of Set 11 | la palma
# Processing Record 12 of Set 11 | vanderhoof
# Processing Record 13 of Set 11 | bonham
# Processing Record 14 of Set 11 | bilma
# Processing Record 15 of Set 11 | mabaruma
# Processing Record 16 of Set 11 | yeletskiy
# City not found. Skipping...
# Processing Record 17 of Set 11 | general roca
# Processing Record 18 of Set 11 | bisert
# Processing Record 19 of Set 11 | pestisu mic
# Processing Record 20 of Set 11 | cheremushskiy
# Processing Record 21 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 22 of Set 11 | vila
# Processing Record 23 of Set 11 | natal
# Processing Record 24 of Set 11 | dentsville
# Processing Record 25 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 11 | buala
# Processing Record 27 of Set 11 | high level
# Processing Record 28 of Set 11 | aranos
# Processing Record 29 of Set 11 | vallenar
# Processing Record 30 of Set 11 | middle island
# Processing Record 31 of Set 11 | nemuro
# Processing Record 32 of Set 11 | channel-port aux basques
# Processing Record 33 of Set 11 | anadyr
# Processing Record 34 of Set 11 | oktyabrskiy
# Processing Record 35 of Set 11 | port hedland
# Processing Record 36 of Set 11 | miranorte
# City not found. Skipping...
# Processing Record 37 of Set 11 | otukpo
# Processing Record 38 of Set 11 | ust-koksa
# Processing Record 39 of Set 11 | khao wong
# Processing Record 40 of Set 11 | kangaatsiaq
# Processing Record 41 of Set 11 | nanortalik
# Processing Record 42 of Set 11 | mattru
# Processing Record 43 of Set 11 | evensk
# Processing Record 44 of Set 11 | oistins
# Processing Record 45 of Set 11 | san juan
# Processing Record 46 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 47 of Set 11 | nevers
# Processing Record 48 of Set 11 | monywa
# Processing Record 49 of Set 11 | chuka
# Processing Record 0 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 1 of Set 12 | owando
# Processing Record 2 of Set 12 | ipora
# Processing Record 3 of Set 12 | moerai
# Processing Record 4 of Set 12 | nhulunbuy
# Processing Record 5 of Set 12 | neuquen
# Processing Record 6 of Set 12 | djenne
# Processing Record 7 of Set 12 | pinawa
# Processing Record 8 of Set 12 | syamzha
# Processing Record 9 of Set 12 | piacabucu
# Processing Record 10 of Set 12 | nuuk
# Processing Record 11 of Set 12 | verkhnetulomskiy
# Processing Record 12 of Set 12 | sovetskiy
# Processing Record 13 of Set 12 | yeroham
# Processing Record 14 of Set 12 | krasnotorka
# Processing Record 15 of Set 12 | damaturu
# Processing Record 16 of Set 12 | gat
# Processing Record 17 of Set 12 | ahuimanu
# Processing Record 18 of Set 12 | sao jose da coroa grande
# Processing Record 19 of Set 12 | oxford
# Processing Record 20 of Set 12 | salou
# Processing Record 21 of Set 12 | opuwo
# Processing Record 22 of Set 12 | svetlogorsk
# Processing Record 23 of Set 12 | college
# Processing Record 24 of Set 12 | bumba
# Processing Record 25 of Set 12 | verkhniy fiagdon
# Processing Record 26 of Set 12 | san juan del sur
# Processing Record 27 of Set 12 | talisay
# Processing Record 28 of Set 12 | bismarck
# Processing Record 29 of Set 12 | christiana
# Processing Record 30 of Set 12 | otane
# Processing Record 31 of Set 12 | korla
# Processing Record 32 of Set 12 | sinnamary
# Processing Record 33 of Set 12 | gravdal
# Processing Record 34 of Set 12 | sikonge
# Processing Record 35 of Set 12 | nacala
# Processing Record 36 of Set 12 | hirtshals
# Processing Record 37 of Set 12 | sharkan
# Processing Record 38 of Set 12 | atbasar
# Processing Record 39 of Set 12 | almaznyy
# Processing Record 40 of Set 12 | tiznit
# Processing Record 41 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 12 | lebork
# Processing Record 43 of Set 12 | palafrugell
# Processing Record 44 of Set 12 | ola
# Processing Record 45 of Set 12 | airai
# Processing Record 46 of Set 12 | tripoli
# Processing Record 47 of Set 12 | sandpoint
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
citi_data_df = pd.DataFrame(citi_data)

# Show Record Count
citi_data_df.count()
# Out:
# City          550
# Lat           550
# Lng           550
# Max Temp      550
# Humidity      550
# Cloudiness    550
# Wind Speed    550
# Country       550
# Date          550
# dtype: int64

# %%
# Display sample data
citi_data_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      inuvik  68.3499 -133.7218    -23.52        77         100        4.12
# 1     vaitape -16.5167 -151.7500     27.64        75         100        4.36
# 2       ejura   7.3856   -1.3562     36.03        28          64        1.05
# 3  swellendam -34.0226   20.4417     25.03        53           0        4.16
# 4   esperance -33.8667  121.9000     19.10        88          77        3.58
#
#   Country        Date
# 0      CA  1678724369
# 1      PF  1678724369
# 2      GH  1678724189
# 3      ZA  1678724370
# 4      AU  1678724370

# %%
# Export the cities_data into a csv
citi_data_df.to_csv("output_data/ciudades.csv", index_label="City_ID")

# %%
# Read saved data
citi_data_df = pd.read_csv("output_data/ciudades.csv", index_col="City_ID")

# Display sample data
citi_data_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            inuvik  68.3499 -133.7218    -23.52        77         100
# 1           vaitape -16.5167 -151.7500     27.64        75         100
# 2             ejura   7.3856   -1.3562     36.03        28          64
# 3        swellendam -34.0226   20.4417     25.03        53           0
# 4         esperance -33.8667  121.9000     19.10        88          77
#
#          Wind Speed Country        Date
# City_ID
# 0              4.12      CA  1678724369
# 1              4.36      PF  1678724369
# 2              1.05      GH  1678724189
# 3              4.16      ZA  1678724370
# 4              3.58      AU  1678724370

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
ax1 = citi_data_df.plot.scatter(x='Lat', y='Max Temp',edgecolor='black',alpha=0.8, marker='o')

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature 2023-01-28")
plt.ylabel("Max Temperature (C)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
ax1 = citi_data_df.plot.scatter(
    x='Lat', y='Humidity', edgecolor='black', alpha=0.8, marker='o')


# Incorporate the other graph properties
plt.title("City Latidude vs. Humidity 2023-01-28")
plt.ylabel("Humidity (%)")
plt.xlabel("Latidude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
ax1 = citi_data_df.plot.scatter(
    x='Lat', y='Cloudiness', edgecolor='black', alpha=0.8, marker='o')

# Incorporate the other graph properties
plt.title("City Latiditude vs. Cloudiness 2023-01-28")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
ax1 = citi_data_df.plot.scatter(
    x='Lat', y='Wind Speed', edgecolor='black', alpha=0.8, marker='o')

# Incorporate the other graph properties
plt.title("City Latiditude vs. Wind Speed 2023-01-28")
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, text_coordinates):

    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r-")
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.xlabel('Latitude')
    plt.ylabel(title)
    print(f"The r-value is: {rvalue**2}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
north_df = citi_data_df.loc[(citi_data_df["Lat"] >= 0)]

# Display sample data
north_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            inuvik  68.3499 -133.7218    -23.52        77         100
# 2             ejura   7.3856   -1.3562     36.03        28          64
# 5           hoquiam  46.9809 -123.8893      6.27        97         100
# 7        georgetown   5.4112  100.3354     26.96        78          20
# 8           okhotsk  59.3833  143.3000     -7.46        95         100
#
#          Wind Speed Country        Date
# City_ID
# 0              4.12      CA  1678724369
# 2              1.05      GH  1678724189
# 5              3.02      US  1678724264
# 7              0.00      MY  1678724148
# 8              4.96      RU  1678724371

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
south_df = citi_data_df.loc[(citi_data_df["Lat"] < 0)]

# Display sample data
south_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1           vaitape -16.5167 -151.7500     27.64        75         100
# 3        swellendam -34.0226   20.4417     25.03        53           0
# 4         esperance -33.8667  121.9000     19.10        88          77
# 6          necochea -38.5473  -58.7368     33.63        34          35
# 9            atuona  -9.8000 -139.0333     26.03        78          28
#
#          Wind Speed Country        Date
# City_ID
# 1              4.36      PF  1678724369
# 3              4.16      ZA  1678724370
# 4              3.58      AU  1678724370
# 6              6.01      AR  1678724371
# 9              3.44      PF  1678724371

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = north_df["Lat"]
y_values = north_df["Max Temp"]
plot_linear_regression(x_values, y_values, 'Max Temp',(5,-30))
# Out:
# The r-value is: 0.7821156727448333

# %%
# Linear regression on Southern Hemisphere
x_values = south_df["Lat"]
y_values = south_df["Max Temp"]
plot_linear_regression(x_values, y_values, 'Max Temp',(-30,35))
# Out:
# The r-value is: 0.2756731653583029

# %% [markdown]
# **Discussion about the linear relationship:** There is a strong correlation between latitude and temperature in the north hemisphere. In the south hemisphere, on the other hand, the temperature is little affected by the elevation of the studied ciudades.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = north_df["Lat"]
y_values = north_df["Humidity"]
plot_linear_regression(x_values, y_values, 'Humidity',(40,20))
# Out:
# The r-value is: 0.18073430755981046

# %%
# Southern Hemisphere
x_values = south_df["Lat"]
y_values = south_df["Humidity"]
plot_linear_regression(x_values, y_values, 'Humidity',(-25,20))
# Out:
# The r-value is: 0.029685838938728407

# %% [markdown]
# **Discussion about the linear relationship:** Following the trend on temperature, the correlation between humidity and latitute is higher in the north hemisphere, but on an much smaller rate than the temperature. Both hemispheres have a weak correlation Humidity vs Latitute.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = north_df["Lat"]
y_values = north_df["Cloudiness"]
plot_linear_regression(x_values, y_values, 'Cloudiness',(40,20))
# Out:
# The r-value is: 0.06696835269658327

# %%
# Southern Hemisphere
x_values = south_df["Lat"]
y_values = south_df["Cloudiness"]
plot_linear_regression(x_values, y_values, 'Cloudiness',(40,20))
# Out:
# The r-value is: 0.15039724986848466

# %% [markdown]
# **Discussion about the linear relationship:** While there is some correlation between cloudiness and latitude in the north hemisphere, it is almost inexistent in the south hemisphere.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = north_df["Lat"]
y_values = north_df["Wind Speed"]
plot_linear_regression(x_values, y_values, 'Wind Speed',(10,14))
# Out:
# The r-value is: 0.017155964155228166

# %%
# Southern Hemisphere
x_values = south_df["Lat"]
y_values = south_df["Wind Speed"]
plot_linear_regression(x_values, y_values, 'Wind Speed',(-55,9))
# Out:
# The r-value is: 0.039460034050383154

# %% [markdown]
# **Discussion about the linear relationship:** No correlation between wind speed and latituted on both hemispheres.
